# %%
# !pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\suyas\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\suyas\anaconda3\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.53.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (8.2.3)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\suyas\anaconda3\lib\site-packages (from google-genai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\suyas\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\suyas\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\suyas\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (43.0.0)
# Requirement already satisfied: certifi in c:\users\suyas\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\suyas\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\suyas\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\suyas\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\suyas\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\suyas\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\suyas\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\suyas\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.2.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\suyas\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (1.17.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\suyas\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.8)
# Requirement already satisfied: pycparser in c:\users\suyas\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.21)

# %%
from dotenv import load_dotenv
import os
from google import genai

load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")

# %%
from google import genai

# %% [markdown]
# Using Client Class

# %%
client = genai.Client(api_key=api_key)

# %%
def study_assistant(user_prompt):
    response=client.models.generate_content(
        model="gemini-2.5-flash",
        contents=user_prompt
    )
    return response

# %%
output=study_assistant("what is gen ai")
print(output.text)
# Out:
# **Generative AI (Gen AI)** is a type of artificial intelligence that can **create new, original content** rather than just analyzing or classifying existing data.
#
# Think of it this way:
# *   **Traditional AI** might *recognize* a cat in an image, *predict* stock prices, or *translate* a language.
# *   **Generative AI** can *draw* a new picture of a cat, *write* a poem about the stock market, or *compose* a song in a new language.
#
# ---
#
# Here's a breakdown of what that means:
#
# 1.  **Creation, Not Just Analysis:** Its core capability is to generate novel output that didn't exist before. This output can be text, images, audio, video, code, 3D models, and more.
#
# 2.  **Learning from Patterns:** Generative AI models are trained on vast amounts of existing data (e.g., millions of text documents, images, sound clips). During this training, they learn the underlying patterns, structures, styles, and relationships within that data.
#
# 3.  **Responding to Prompts:** Once trained, a Gen AI model can take an input (often called a "prompt") from a user and use its learned knowledge to generate new content that fits the prompt's instructions and resembles the style and characteristics of its training data, but is unique.
#
#     *   **Example Prompt (Text):** "Write a short sci-fi story about a rogue AI that falls in love with a human."
#     *   **Example Prompt (Image):** "Generate an image of an astronaut riding a horse on the moon in a realistic style."
#
# 4.  **Key Technologies:**
#     *   **Large Language Models (LLMs):** Like ChatGPT, Bard (now Gemini), and Claude, which specialize in generating human-like text, code, summaries, translations, etc.
#     *   **Diffusion Models:** Used for generating highly realistic images (e.g., DALL-E, Midjourney, Stable Diffusion).
#     *   **Generative Adversarial Networks (GANs):** Another class of models often used for image generation and synthesis.
#
# ---
#
# **What can Generative AI create?**
#
# *   **Text:** Articles, stories, poems, emails, summaries, code, scripts, chatbots, translations.
# *   **Images:** Realistic photos, artistic illustrations, logos, product designs, variations of existing images.
# *   **Audio:** Music compositions, voiceovers, sound effects, synthetic speech.
# *   **Video:** Short clips, animations, deepfakes, video editing, generating video from text.
# *   **Code:** Programming functions, entire scripts, debugging suggestions.
# *   **3D Models:** For gaming, architectural visualization, product design.
#
# ---
#
# **Why is it a big deal?**
#
# *   **Boosts Creativity & Productivity:** It can assist humans in creative tasks, automate content creation, and accelerate design processes.
# *   **Personalization:** Enables highly customized content tailored to individual preferences.
# *   **Accessibility:** Lowers the barrier for creating high-quality content that previously required specialized skills or tools.
# *   **Innovation:** Opens up entirely new possibilities for applications across industries, from entertainment and marketing to scientific research and education.
#
# ---
#
# **Challenges and Concerns:**
#
# *   **Accuracy & "Hallucinations":** Gen AI models can sometimes generate factually incorrect or nonsensical information.
# *   **Bias:** They can perpetuate and amplify biases present in their training data.
# *   **Misinformation & Deepfakes:** The ability to generate realistic fake content raises concerns about the spread of misinformation and manipulation.
# *   **Copyright & Ownership:** Questions arise about who owns content created by AI and what constitutes plagiarism.
# *   **Job Displacement:** Potential impact on jobs in creative industries and content creation.
#
# ---
#
# In essence, Generative AI is a powerful and rapidly evolving field that is fundamentally changing how we interact with technology and create content.

# %% [markdown]
# Checking Availabel Models

# %%
for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview
