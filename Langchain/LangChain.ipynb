# %%
pip install -U langchain langchain-google-genai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
  "google_genai:gemini-2.5-flash",
  api_key=api_key,
)

# %%
from langchain.messages import HumanMessage, SystemMessage
system_msg = SystemMessage("You are a helpful assistant.")# behaviour of model
human_msg = HumanMessage("What are AI Agents?")# user_input
messages = [system_msg, human_msg]

# %%
response = model.invoke(messages)#method to Rqst the model
print(response.content)
# Out:
# An **AI Agent** is an autonomous entity, whether software or hardware, that perceives its environment through sensors, processes that information, makes decisions, and acts upon that environment through effectors to achieve specific goals.
#
# It's a foundational concept in Artificial Intelligence, representing a system that can operate somewhat independently, without constant human intervention, to perform tasks.
#
# Here's a breakdown of what that means:
#
# 1.  **Perceives (Sensors):** An AI agent takes in information about its surroundings.
#     *   **For software agents:** This could be data from databases, user input, website content, API responses, sensor readings from a smart home system, or text/image input for an LLM.
#     *   **For hardware agents (robots):** This involves physical sensors like cameras, microphones, lidar, radar, touch sensors, GPS, etc.
#
# ...
