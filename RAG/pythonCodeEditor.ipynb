# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language
# Out:
# C:\Users\suyas\AppData\Local\Temp\ipykernel_15300\1107173689.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("filePath")
documents = loader.load()

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    separators=RecursiveCharacterTextSplitter.get_separators_for_language(
        Language.PYTHON
    )
)

# %%
print("Total number of chunks:", len(chunks))
print("\nFirst Chunk:")
print(chunks[0].page_content)
print("\nSecond Chunk:")
print(chunks[1].page_content)
